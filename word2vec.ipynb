# %%
import pandas as pd

# %%
data = pd.read_csv("covid19_tweeter_dataset.csv")

# %%
data
# Out:
#        Unnamed: 0  Label                   Datetime  \
# 0               0     -1  2021-01-10 22:06:41+00:00
# 1               1     -1  2021-01-10 17:49:34+00:00
# 2               2      1  2021-01-10 16:18:34+00:00
# 3               3      0  2021-01-10 15:12:17+00:00
# 4               4     -1  2021-01-10 15:07:12+00:00
# ...           ...    ...                        ...
# 33469       33469      0  2020-02-12 01:33:08+00:00
# 33470       33470      0  2020-02-12 00:38:07+00:00
# 33471       33471      0  2020-02-11 19:37:26+00:00
# 33472       33472      0  2020-02-11 16:36:40+00:00
# 33473       33473      0  2020-02-11 15:22:16+00:00
#
#                                                    Tweet  \
# 0      अमेरिकामा कोभिड बाट एकै दिन चार हजारभन्दा बढीक...
# 1      कोभिड का कारण विदेशमा रहेका नेपालीहरुमा मानसिक...
# 2      नेपालमा क्लोभर बायोफार्मास्युटिकल्स अस्ट्रेलिय...
# 3                                कोभिड को खोप पनि लगाइयो
# 4      अमेरिकामा कोभिड को नयाँ रेकर्ड एकै दिन हजारभन्...
# ...                                                  ...
# 33469  कोरोना भाइरसलाई विश्व स्वास्थ्य संगठनले दियो न...
# 33470       डब्ल्युएचओले दियाेको कोरोनाको नयाँ नाम कोभिड
# 33471        कोरोना भाइरस संक्रमणको औपचारिक नाम अब कोभिड
# 33472  विश्व स्वास्थ्य संगठन डब्लुएचओ ले नोबल कोरोना ...
# 33473  कोरोनाभाइरसका सङ्क्रमणको नाम कोभिड भनेर विश्व ...
#
#                                           Tokanize_tweet Unnamed: 5
# 0      अमेरिकामा,कोभिड,बाट,एकै,दिन,चार,हजारभन्दा,बढीक...        NaN
# 1      कोभिड,का,कारण,विदेशमा,रहेका,नेपालीहरुमा,मानसिक...        NaN
# 2      नेपालमा,क्लोभर,बायोफार्मास्युटिकल्स,अस्ट्रेलिय...        NaN
# 3                                कोभिड,को,खोप,पनि,लगाइयो        NaN
# 4      अमेरिकामा,कोभिड,को,नयाँ,रेकर्ड,एकै,दिन,हजारभन्...        NaN
# ...                                                  ...        ...
# 33469  कोरोना,भाइरसलाई,विश्व,स्वास्थ्य,संगठनले,नाम,कोभिड        NaN
# 33470            डब्ल्युएचओले,दियाेको,कोरोनाको,नाम,कोभिड        NaN
# 33471           कोरोना,भाइरस,संक्रमणको,औपचारिक,नाम,कोभिड        NaN
# 33472  विश्व,स्वास्थ्य,संगठन,डब्लुएचओ,नोबल,कोरोना,भाइ...        NaN
# 33473  कोरोनाभाइरसका,सङ्क्रमणको,नाम,कोभिड,विश्व,स्वास...        NaN
#
# [33474 rows x 6 columns]

# %%
data['Tweet'][30]
# Out:
# 'प्रधानमँत्रीज्यू चुनाव गर्ने पैसा हुने तर कोभीड बाट जनताको लागि निशूल्क खोप ल्याउन पैसा नहुने खोप ल्याउन किन ढिलाइ गरिँदैछ देश र जनताप्रति किन लापरबाही'

# %%
data['length'] = data['Tokanize_tweet'].apply(
    lambda row: min(len(row.split(",")), len(row)) if isinstance(row, str) else None
)

# %%
max(data['length'].tolist())
# Out:
# 61.0

# %%
data["Tweet"][1]
# Out:
# 'कोभिड का कारण विदेशमा रहेका नेपालीहरुमा मानसिक स्वास्थ्य सम्बन्धि समस्या देखिएको र आत्महत्याका घटनाहरु बढेको डा सापकोटाले बताए'

# %%
data.head()
# Out:
#    Unnamed: 0  Label                   Datetime  \
# 0           0     -1  2021-01-10 22:06:41+00:00
# 1           1     -1  2021-01-10 17:49:34+00:00
# 2           2      1  2021-01-10 16:18:34+00:00
# 3           3      0  2021-01-10 15:12:17+00:00
# 4           4     -1  2021-01-10 15:07:12+00:00
#
#                                                Tweet  \
# 0  अमेरिकामा कोभिड बाट एकै दिन चार हजारभन्दा बढीक...
# 1  कोभिड का कारण विदेशमा रहेका नेपालीहरुमा मानसिक...
# 2  नेपालमा क्लोभर बायोफार्मास्युटिकल्स अस्ट्रेलिय...
# 3                            कोभिड को खोप पनि लगाइयो
# 4  अमेरिकामा कोभिड को नयाँ रेकर्ड एकै दिन हजारभन्...
#
#                                       Tokanize_tweet Unnamed: 5  length
# 0  अमेरिकामा,कोभिड,बाट,एकै,दिन,चार,हजारभन्दा,बढीक...        NaN     9.0
# 1  कोभिड,का,कारण,विदेशमा,रहेका,नेपालीहरुमा,मानसिक...        NaN    18.0
# 2  नेपालमा,क्लोभर,बायोफार्मास्युटिकल्स,अस्ट्रेलिय...        NaN    20.0
# 3                            कोभिड,को,खोप,पनि,लगाइयो        NaN     5.0
# 4  अमेरिकामा,कोभिड,को,नयाँ,रेकर्ड,एकै,दिन,हजारभन्...        NaN    12.0

# %%
data["Tokanize_tweet"][1]
# Out:
# 'कोभिड,का,कारण,विदेशमा,रहेका,नेपालीहरुमा,मानसिक,स्वास्थ्य,सम्बन्धि,समस्या,देखिएको,र,आत्महत्याका,घटनाहरु,बढेको,डा,सापकोटाले,बताए'

# %%
data["Label"].value_counts()
# Out:
#  1    14998
# -1    13606
#  0     4870
# Name: Label, dtype: int64

# %%
from gensim.models.keyedvectors import KeyedVectors
from gensim.models import Word2Vec
import numpy as np

class Sabda2Vec():
    def __init__(self,model_name):
        """
        Constructor for loading sabda2vec model and getting vocab list
        """
        self.model_name = KeyedVectors.load("/home/fm-pc-lt-228/Desktop/covid_nepali_tweets/sabda_to_vec_model_md")


    
    def get_most_similar(self,token,num_of_similar_tokens):
        """
        Get most similar tokens from the loaded sabda2vec model.
        params: token: str
                num_of_similar_tokens: int
        return: similar_tokens : list of tuples
        """
        most_similar = self.model_name.wv.most_similar_cosmul(positive=[token], topn=num_of_similar_tokens)
        return most_similar

    def get_embedding(self,token):
        """
        Get the vector embedding of the token from the loaded model.
        params: token: str
        return: embedding : numpy_array
        """
        try:
            token_embedding = self.model_name.wv[token]
        except KeyError:
            print("The word {} does not appear in this model".format(token))
            token_embedding = np.zeros(100)
        return token_embedding

    def get_similarity_between_tokens(self,token1,token2):
        """
        Get the similarity between two nepali tokens
        params: token1 : str
                token2: str
        return: simalarity_score: float
        """
        try:
            similarity_score = self.model_name.wv.similarity(token1,token2)
            return similarity_score
        except KeyError:
            print("One of the word  does not appear in this model")
            return 0
    
    def get_sentence_embedding(self,sent):
        tokens = sent.split(",")
        tokens_embedding = [self.get_embedding(tok) for tok in tokens]
        sent_emb = np.mean(tokens_embedding,axis = 0)
        return sent_emb

# %%
s2v_object = Sabda2Vec("sabda2vec_md")

# %%
sent_em = s2v_object.get_sentence_embedding("कोभिड,का,कारण,विदेशमा,रहेका,नेपालीहरुमा,मानसिक,स्वास्थ्य,सम्बन्धि,समस्या,देखिएको,र,आत्महत्याका,घटनाहरु,बढेको,डा,सापकोटाले,बताए")
# Out:
# The word कोभिड does not appear in this model

# %%
tweets = data["Tokanize_tweet"].tolist()

# %%
tweets_embedding = []
for i,tweet in enumerate(tweets):
    try:
        emb = s2v_object.get_sentence_embedding(tweet)
    except:
        print("mistake",i)
    tweets_embedding.append(emb)
# Out:
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word बायोफार्मास्युटिकल्स does not appear in this model
# The word भ्याक्जाइन does not appear in this model
# The word पीटीवाई does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word प्रभावीतहरुको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word संक्रामकको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word प्रधानमँत्रीज्यू does not appear in this model
# The word कोभीड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरोनभाइरस does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word डब्ल्युएचओका does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word लोहरी does not appear in this model
# The word पोङ्गल does not appear in this model
# The word बिहू does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word सक्किनु does not appear in this model
# The word छकसैलाई does not appear in this model
# The word कोभिड does not appear in this model
# The word डब्ल्यूएचओलाई does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word सेरमका does not appear in this model
# The word प्रहाप्रवन्धकसँग does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word इस्टिच्युटका does not appear in this model
# The word प्रसेन does not appear in this model
# The word अद्यासँग does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word ओम्नि does not appear in this model
# The word स्वास्थसामाग्री does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word सफाईकर्मी does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word बेमौसमिवाला does not appear in this model
# The word बचनद्वारा does not appear in this model
# The word कोभिड does not appear in this model
# The word सफाईकर्मी does not appear in this model
# The word कोभीड़ does not appear in this model
# The word जूलस does not appear in this model
# The word पर्बा does not appear in this model
# The word कोभिड does not appear in this model
# The word स्वास्थ्यसुरक्षा does not appear in this model
# The word अयातोल्लाह does not appear in this model
# The word खामिनीले does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word स्वास्थ्यसुरक्षा does not appear in this model
# The word कोभिड does not appear in this model
# The word स्वास्थ्यसुरक्षा does not appear in this model
# The word कोभिड does not appear in this model
# The word खटिनेहरूको does not appear in this model
# The word आरटीआईले does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउनका does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउनको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिडको does not appear in this model
# The word कोभिड does not appear in this model
# The word देखिएदेखि does not appear in this model
# The word सॅंग does not appear in this model
# The word कोभीड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word मोडेर्नाले does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word सृहनशिल does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word जोखिमसङ्ग does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word पुनर्उत्थानका does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभीड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word बायोटेकको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरोनाविरुद्धको does not appear in this model
# The word कोरोनाविरुद्धको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभीड does not appear in this model
# The word कोभिड does not appear in this model
# The word नलगाऊन does not appear in this model
# The word कोभिड does not appear in this model
# The word तैरिनै does not appear in this model
# The word प्रजातिसहितको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word पीपीईको does not appear in this model
# The word कोभिड does not appear in this model
# The word याबाइ does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word छुटाइरहेको does not appear in this model
# The word कोभिड does not appear in this model
# The word डाउनिङले does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभीड does not appear in this model
# The word कोरोनाभाइरस does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभीड does not appear in this model
# The word कोभीडको does not appear in this model
# The word नविसौँ does not appear in this model
# The word लाईखोप does not appear in this model
# The word लकडाउन does not appear in this model
# The word टीकाबारे does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउन does not appear in this model
# The word कोभिड does not appear in this model
# The word भेरियन्टबाट does not appear in this model
# The word कोभिड does not appear in this model
# The word खुस्किरहेको does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउन does not appear in this model
# The word नमानेकाहरू does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word महामारीजस्तै does not appear in this model
# The word पार्नेछैन् does not appear in this model
# The word कोभिड does not appear in this model
# The word सुन्यजस्तै does not appear in this model
# The word लकडाउन does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word पेचिङका does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word स्ट्रेलियाको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word बन्दाबन्दीका does not appear in this model
# The word कोभिड does not appear in this model
# The word बेरालाको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरोनाभाइरस does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word सीसीएमसीको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word रिभ्यूड does not appear in this model
# The word इफिकेसी does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word पोजिटिभलाई does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word रिप्रोडक्सन does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word बेरालामा does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word डीसीजीआई does not appear in this model
# The word बायोटेकको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word याहि does not appear in this model
# The word कोभिड does not appear in this model
# The word अनतर्कृिया does not appear in this model
# The word बायोटेकको does not appear in this model
# The word कोभिड does not appear in this model
# The word बायोटेकको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word एस्ट्राजेनेका does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word शेयरिङमा does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word अस्ट्रेलियालीहरु does not appear in this model
# The word सेप्टेमवर does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word अाफुँपनि does not appear in this model
# The word अरुलाईनि does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word प्रियजनसँगै does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word होवार्ट does not appear in this model
# The word हुरिकेन्सबाट does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word प्रियजनसँगै does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरोनाका does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word निशेधाज्ञाको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word महाअवसरका does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word निशेधाज्ञाको does not appear in this model
# The word कोभिड does not appear in this model
# The word याइरहेको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word बायोएनटेकसँग does not appear in this model
# The word कोभिड does not appear in this model
# The word एस्ट्राजेनेकासँग does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word बायोएनटेकको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word बायोएनटेकले does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word बायोनटेकको does not appear in this model
# The word कोभिड does not appear in this model
# The word बायोएनटेकले does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word बायोएनटेक does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word हटिजावस् does not appear in this model
# The word थालनिहोस्देश does not appear in this model
# The word होस्जय does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word गुल्महरुको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word साइनोफर्मले does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउन does not appear in this model
# The word क्वारेनटाइन does not appear in this model
# The word लोकसंवाद does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word ट्रम्पमाथिको does not appear in this model
# The word महाअभियोगसम्मका does not appear in this model
# The word कोभिड does not appear in this model
# The word एस्ट्राजेनेकाको does not appear in this model
# The word कोभिड does not appear in this model
# The word छाहोस does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिडविरुद्ध does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word ट्रम्पमाथिको does not appear in this model
# The word महाअभियोगसम्मका does not appear in this model
# The word कोभिड does not appear in this model
# The word कोर्नाले does not appear in this model
# The word भोलिया does not appear in this model
# The word टेक्च does not appear in this model
# The word मानुभाउहरुलाई does not appear in this model
# The word कोर्ना does not appear in this model
# The word शौति does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word जिउंदैपनि does not appear in this model
# The word आफ्नासंग does not appear in this model
# The word शुन्यतिर does not appear in this model
# The word पिडानै does not appear in this model
# The word कोभिड does not appear in this model
# The word ख्रिस्टमस does not appear in this model
# The word ट्रेसिङमा does not appear in this model
# The word कोभिड does not appear in this model
# The word नेगेटिभको does not appear in this model
# The word प्रोटोकलसहित does not appear in this model
# The word घरबेटीलेे does not appear in this model
# The word कोभिड does not appear in this model
# The word सिनोफार्मको does not appear in this model
# The word सिनोफार्म does not appear in this model
# The word कोभिड does not appear in this model
# The word सिनोफार्मका does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरोनाले does not appear in this model
# The word लगाइयोमानव does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरोनाभाइरसबारे does not appear in this model
# The word क्वात्रालाई does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word डिजिटाजेसन does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word सिनोफार्म does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word सिनोफार्म does not appear in this model
# The word छदशैंताका does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कहरबीच does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word जनसंख्यालई does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word सम्मन् does not appear in this model
# The word धुर्मुसेको does not appear in this model
# The word मिठाइलालको does not appear in this model
# The word कोभाक्स does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभाक्समा does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कार्यकर्ताहरुप्रति does not appear in this model
# The word व्यंग्यवाणपूर्ण does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word निस्कियोअब does not appear in this model
# The word सतरन्ज does not appear in this model
# The word भैइसक्यो does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word अस्ट्राजेनिकाको does not appear in this model
# The word मोडर्नाको does not appear in this model
# The word अस्ट्राजेनिकाद्वारा does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word एक्सट्राजेनेकाद्धारा does not appear in this model
# The word अस्ट्राजेनिकाद्वारा does not appear in this model
# The word कोभिड does not appear in this model
# The word पोखरेलं does not appear in this model
# The word कोभिड does not appear in this model
# The word त्याकेफुगु does not appear in this model
# The word देशया does not appear in this model
# The word धलखँय् does not appear in this model
# The word बालांगु does not appear in this model
# The word यागु does not appear in this model
# The word देयया does not appear in this model
# The word पङ्तिइ does not appear in this model
# The word धयादिगु does not appear in this model
# The word अस्ट्राजेनिकाद्वारा does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word सिनोफर्मले does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word जोशीजी does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word मोडर्नाको does not appear in this model
# The word अस्ट्राजेनिकाद्वारा does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word अस्ट्राजेनेकासँग does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word भ्याक्सिन् does not appear in this model
# The word नलिईन does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word लेरआउ does not appear in this model
# The word आउनैआटो does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word शनिवारबाहेक does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word नियंत्रणका does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word हुदैछ्न does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरना does not appear in this model
# The word जिकिनकी does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word लाष्टै does not appear in this model
# The word भारैभार does not appear in this model
# The word लीलाभिलासमा does not appear in this model
# The word सलबलाहटको does not appear in this model
# The word कोभिड does not appear in this model
# The word लगाउँनुपर्ने does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिडमा does not appear in this model
# The word कोरोनाले does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word रिभरबीच does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word मानोपरामर्श does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word यहाॅंको does not appear in this model
# The word स्मनहोस does not appear in this model
# The word बाॅंकी does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिडको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word मन्दीरहरुले does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word थन्क्याईदियो does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word होतसैले does not appear in this model
# The word बैज्ञानिकहरू does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word अनदुडाँडाको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word अनदुडाँडाको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरोनाभाइरस does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word सघाउनेलाई does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word सुरक्षितचाडपर्व does not appear in this model
# The word कोभिड does not appear in this model
# The word अनदुडाँडाको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word एजेडडी does not appear in this model
# The word कोभिड does not appear in this model
# The word अर्नैपरो does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word रोक्नपरे does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word रेन्त does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word विघटनविरुद्ध does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word विश्वखुशी does not appear in this model
# The word कोभिड does not appear in this model
# The word याट्खामा does not appear in this model
# The word कोभिड does not appear in this model
# The word अाफुँपनि does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word दाइरस does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word थियोहाच्छ्यु does not appear in this model
# The word साच्छ्यु does not appear in this model
# The word उडाइयोअब does not appear in this model
# The word कोभिड does not appear in this model
# The word युरोपतिरबाटमेड does not appear in this model
# The word बेलायतयसलाई does not appear in this model
# The word निलोहे does not appear in this model
# The word लोहेको does not appear in this model
# The word काटता does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरोनाको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word औरिकाको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word गाईवाच्छा does not appear in this model
# The word डाेल does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word एक्स्ट्राजेनेकाले does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word च्यवनप्राशको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभीड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभोड does not appear in this model
# The word कोभिड does not appear in this model
# The word पुगिरहदा does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउनमा does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word बृटेनले does not appear in this model
# The word दिनदुखिको does not appear in this model
# The word बायोएनटेक does not appear in this model
# The word कोभिड does not appear in this model
# The word वुधबारबाट does not appear in this model
# The word कोभिड does not appear in this model
# The word क्वारेन्टिनमा does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word बन्दाबन्दीपछि does not appear in this model
# The word कोभिड does not appear in this model
# The word बन्दाबन्दीपछि does not appear in this model
# The word कोभिड does not appear in this model
# The word खर्चलाइ does not appear in this model
# The word एकमुष्ठमा does not appear in this model
# The word कोभिड does not appear in this model
# The word इम्युुनिटी does not appear in this model
# The word अर्थतन्त्रसम्बद्ध does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word डिजिटाइजेशनको does not appear in this model
# The word पडकाष्टको does not appear in this model
# The word अर्थविद्हरुका does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word भर्चुअलमार्फत does not appear in this model
# The word ग्यालरीकाे does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word रिन्हो does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word स्वास्थ्यकर्मीहरुमध्ये does not appear in this model
# The word कोभिड does not appear in this model
# The word लक्ष्णा does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word भाक्सिन does not appear in this model
# The word चहियको does not appear in this model
# The word बायोएनटेकले does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word साथीसंगीकै does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरोनाभाइरस does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word बाइडेनलाई does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word झुक्किनुहुन्न does not appear in this model
# The word भगाउ does not appear in this model
# The word कोभिड does not appear in this model
# The word बाइडेनलाई does not appear in this model
# The word कोभिड does not appear in this model
# The word बाइडेनले does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरोनाले does not appear in this model
# The word कोभिड does not appear in this model
# The word बाइडेनलाई does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरोनाको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word हटस्पटहरूको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word लुटिराछन does not appear in this model
# The word कलीयुगका does not appear in this model
# The word कोभिड does not appear in this model
# The word नेप्काका does not appear in this model
# The word दुरीसहित does not appear in this model
# The word अर्नला does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरोनाले does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरोनाले does not appear in this model
# The word कोभिड does not appear in this model
# The word थलायो does not appear in this model
# The word बीचेसमा does not appear in this model
# The word कोभिड does not appear in this model
# The word भाइरसमाथि does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word समातौसंसदीय does not appear in this model
# The word नोभोट does not appear in this model
# The word व्यवहारीकरूपमा does not appear in this model
# The word मतबहिष्कार does not appear in this model
# The word सकिन्छकोभीड does not appear in this model
# The word अपसब्दले does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word णेफोलि does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word क्रमित does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word डिस्पोजिवल does not appear in this model
# The word सेनिटाइजर does not appear in this model
# The word स्ट्याड does not appear in this model
# The word र्थमलगन does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word सत्तारोड does not appear in this model
# The word कोभिड does not appear in this model
# The word हुम्ने does not appear in this model
# The word थिएननयसबाट does not appear in this model
# The word सर्वसत्ताबादको does not appear in this model
# The word कोभिड does not appear in this model
# The word अधिनायाकबादले does not appear in this model
# The word कोभिड does not appear in this model
# The word मध्यावधीको does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउन does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउन does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउन does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word प्रोटोकलहरुमा does not appear in this model
# The word गर्दिय does not appear in this model
# The word कोभिड does not appear in this model
# The word जनतालेकाम does not appear in this model
# The word नपायकाले does not appear in this model
# The word सेनेटाईजर does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word बायोएनटेकले does not appear in this model
# The word कोभिड does not appear in this model
# The word कावासाकि does not appear in this model
# The word कोभीडको does not appear in this model
# The word गराउॅंदा does not appear in this model
# The word कोभीड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word लाजनिति does not appear in this model
# The word कोभीड does not appear in this model
# The word जनहीतमाजाहेर does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभीड does not appear in this model
# The word कोभिड does not appear in this model
# The word मुल्यविपरित does not appear in this model
# The word छकोभिड does not appear in this model
# The word विघनको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word मोडर्नाले does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word डब्लुएचओमा does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word नेत्यान्याहुले does not appear in this model
# The word कोभीड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिडले does not appear in this model
# The word मुण्ट्याएर does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउनको does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउन does not appear in this model
# The word सातामका does not appear in this model
# The word लकडाउन does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word डब्लुएचओमा does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word महामार does not appear in this model
# The word कोभिड does not appear in this model
# The word संकटलगायत does not appear in this model
# The word कोभिड does not appear in this model
# The word मााग does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभीड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोपेको does not appear in this model
# The word डब्लुएचओमा does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word डब्लूएचओमा does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word डब्लुएचओमा does not appear in this model
# The word कोभिड does not appear in this model
# The word डब्लुएचओमा does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# ...
# The word लकडाउनमा does not appear in this model
# The word कोरोनाभाइरस does not appear in this model
# The word क्लोरोक्वाईन does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरोनाभाइरस does not appear in this model
# The word क्लोरोक्वाईन does not appear in this model
# The word कोभिड does not appear in this model
# The word क्लोरोक्वाईन does not appear in this model
# The word कोरोनाभाइरसविरुद्ध does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउनलाई does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउनका does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word सुनियाछ does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word वारेन्टाइनमा does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कर्णद्वारा does not appear in this model
# The word आजकोसमाचार does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कर्णद्वारा does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word पीपीई does not appear in this model
# The word क्लोरोक्वाईन does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउन does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word बन्दाबन्दी does not appear in this model
# The word लकडाउन does not appear in this model
# The word भेनेटोको does not appear in this model
# The word कोभिड does not appear in this model
# The word भेनेटोले does not appear in this model
# The word कोरोनाभाइरस does not appear in this model
# The word क्लोरोक्वाईन does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word याइरहेको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउन does not appear in this model
# The word हाेटलबाट does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कर्णद्वारा does not appear in this model
# The word कोभिड does not appear in this model
# The word अपनावोस does not appear in this model
# The word अन्तारालमा does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word आजकोसमाचार does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउन does not appear in this model
# The word कोभिड does not appear in this model
# The word चौधरिहरु does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word स्वास्थ्यसुबिधाका does not appear in this model
# The word कोभिड does not appear in this model
# The word घरमालिकबाट does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरोनाको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरोनाभाईरस does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभीड does not appear in this model
# The word रोकथामाको does not appear in this model
# The word ननिस्किऔ does not appear in this model
# The word धोऔ does not appear in this model
# The word सनिटाइजरको does not appear in this model
# The word प्रयग does not appear in this model
# The word कोरोनाभाइरस does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरोनाभाइरस does not appear in this model
# The word लकडाउन does not appear in this model
# The word घरबन्द does not appear in this model
# The word बन्दाबन्दी does not appear in this model
# The word डिस्ट्यान्डिङ does not appear in this model
# The word क्वारेन्टिन does not appear in this model
# The word प्यान्डामिक does not appear in this model
# The word विश्वमहामारी does not appear in this model
# The word आउटब्रेक does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word सम्मुर्ण does not appear in this model
# The word कोभिड does not appear in this model
# The word गरियोस्संक्रमित does not appear in this model
# The word राखियोस्असंक्रमित does not appear in this model
# The word छोडियोस्कार्यले does not appear in this model
# The word हुनेछसरकार does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word डाउनबारे does not appear in this model
# The word जोडिनुहोला does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word बिश्वदीप does not appear in this model
# The word अञ् does not appear in this model
# The word कोभिड does not appear in this model
# The word आईसोलेसनका does not appear in this model
# The word कोभिड does not appear in this model
# The word प्रणघातक does not appear in this model
# The word फैलाउँ does not appear in this model
# The word कोभिड does not appear in this model
# The word राख्नुोस does not appear in this model
# The word कोभिड does not appear in this model
# The word सेफेरिनले does not appear in this model
# The word कोभिड does not appear in this model
# The word सॅंगै does not appear in this model
# The word कोभिड does not appear in this model
# The word पच्छ्याइरहेछ does not appear in this model
# The word लखेटाइ does not appear in this model
# The word तोडिरहेछ does not appear in this model
# The word पस्किनुस् does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउनबारे does not appear in this model
# The word जोडिनुस् does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word आजकोसमाचार does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभीड does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाऊन does not appear in this model
# The word सेनिटाईजर does not appear in this model
# The word आईसोलेसन does not appear in this model
# The word लकडाऊन does not appear in this model
# The word कोभिड does not appear in this model
# The word साधरणबाट does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word बिश्वनै does not appear in this model
# The word कोभिड does not appear in this model
# The word होविभिन्न does not appear in this model
# The word ससन्कित does not appear in this model
# The word गोवरमेन्ट does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउनका does not appear in this model
# The word होलातिनीहरुका does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word लोकसंवाद does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word सन्क्रमित does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word लड़न does not appear in this model
# The word संगसंग़ै does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word नदेखिईकन does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word जोशजागर does not appear in this model
# The word कोभिड does not appear in this model
# The word मरिदैन does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word पिपिइ does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word नदेखिईकन does not appear in this model
# The word कोभिड does not appear in this model
# The word बिनालक्षण does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउनका does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word छिलकती does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word थर्मोमिटरलगायत does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word हेलच्याक्राइ does not appear in this model
# The word समयमि does not appear in this model
# The word कोभिड does not appear in this model
# The word नदेखिईकन does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word बोउरबोन does not appear in this model
# The word सिक्टस does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word बोउरबोन does not appear in this model
# The word सिक्टस does not appear in this model
# The word कोभिड does not appear in this model
# The word यान्छीले does not appear in this model
# The word पीपीई does not appear in this model
# The word थर्मोमिटरलगायतका does not appear in this model
# The word ग्वाङ्जाओबाट does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word नदेखिईकन does not appear in this model
# The word कोभिड does not appear in this model
# The word बिनालक्षण does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरोनाको does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोरना does not appear in this model
# The word कोभिड does not appear in this model
# The word अातङ्कित does not appear in this model
# The word त्राहिमान does not appear in this model
# The word अरूदेशमा does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word आफुनि does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word छाडदैन does not appear in this model
# The word लकडाउन does not appear in this model
# The word मरिन्दैन does not appear in this model
# The word लकडाउन does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word लकडाउनमा does not appear in this model
# The word कोभिड does not appear in this model
# The word संक्रम does not appear in this model
# The word कोभिड does not appear in this model
# The word ज्युलाइ does not appear in this model
# The word कोभिड does not appear in this model
# The word लेराउ does not appear in this model
# The word नफैलाउ does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word आल्तुफाल्तु does not appear in this model
# The word वारेन्टाइन does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभीड़ does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word जुधन does not appear in this model
# The word बिकाशित does not appear in this model
# The word परदै does not appear in this model
# The word कोभिड does not appear in this model
# The word कोभिड does not appear in this model
# The word चीनीएका does not appear in this model
# The word कोरोनाकै does not appear in this model
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
len(tweets_embedding)
# Out:
# 33474

# %%
len(tweets)
# Out:
# 33474

# %%
data['embeddings']=tweets_embedding

# %%
data
# Out:
#        Unnamed: 0  Label                   Datetime  \
# 0               0     -1  2021-01-10 22:06:41+00:00
# 1               1     -1  2021-01-10 17:49:34+00:00
# 2               2      1  2021-01-10 16:18:34+00:00
# 3               3      0  2021-01-10 15:12:17+00:00
# 4               4     -1  2021-01-10 15:07:12+00:00
# ...           ...    ...                        ...
# 33469       33469      0  2020-02-12 01:33:08+00:00
# 33470       33470      0  2020-02-12 00:38:07+00:00
# 33471       33471      0  2020-02-11 19:37:26+00:00
# 33472       33472      0  2020-02-11 16:36:40+00:00
# 33473       33473      0  2020-02-11 15:22:16+00:00
#
#                                                    Tweet  \
# 0      अमेरिकामा कोभिड बाट एकै दिन चार हजारभन्दा बढीक...
# 1      कोभिड का कारण विदेशमा रहेका नेपालीहरुमा मानसिक...
# 2      नेपालमा क्लोभर बायोफार्मास्युटिकल्स अस्ट्रेलिय...
# 3                                कोभिड को खोप पनि लगाइयो
# 4      अमेरिकामा कोभिड को नयाँ रेकर्ड एकै दिन हजारभन्...
# ...                                                  ...
# 33469  कोरोना भाइरसलाई विश्व स्वास्थ्य संगठनले दियो न...
# 33470       डब्ल्युएचओले दियाेको कोरोनाको नयाँ नाम कोभिड
# 33471        कोरोना भाइरस संक्रमणको औपचारिक नाम अब कोभिड
# 33472  विश्व स्वास्थ्य संगठन डब्लुएचओ ले नोबल कोरोना ...
# 33473  कोरोनाभाइरसका सङ्क्रमणको नाम कोभिड भनेर विश्व ...
#
#                                           Tokanize_tweet Unnamed: 5  length  \
# 0      अमेरिकामा,कोभिड,बाट,एकै,दिन,चार,हजारभन्दा,बढीक...        NaN     9.0
# 1      कोभिड,का,कारण,विदेशमा,रहेका,नेपालीहरुमा,मानसिक...        NaN    18.0
# 2      नेपालमा,क्लोभर,बायोफार्मास्युटिकल्स,अस्ट्रेलिय...        NaN    20.0
# 3                                कोभिड,को,खोप,पनि,लगाइयो        NaN     5.0
# 4      अमेरिकामा,कोभिड,को,नयाँ,रेकर्ड,एकै,दिन,हजारभन्...        NaN    12.0
# ...                                                  ...        ...     ...
# 33469  कोरोना,भाइरसलाई,विश्व,स्वास्थ्य,संगठनले,नाम,कोभिड        NaN     7.0
# 33470            डब्ल्युएचओले,दियाेको,कोरोनाको,नाम,कोभिड        NaN     5.0
# 33471           कोरोना,भाइरस,संक्रमणको,औपचारिक,नाम,कोभिड        NaN     6.0
# 33472  विश्व,स्वास्थ्य,संगठन,डब्लुएचओ,नोबल,कोरोना,भाइ...        NaN    16.0
# 33473  कोरोनाभाइरसका,सङ्क्रमणको,नाम,कोभिड,विश्व,स्वास...        NaN     9.0
#
#                                               embeddings
# 0      [1.1445290015803442, 0.43974624822537106, 3.88...
# 1      [0.9996734211842219, -1.1151447892189026, -0.0...
# 2      [0.01075779739767313, -1.363491040468216, 1.59...
# 3      [-0.6104743897914886, -3.1229610562324526, 1.0...
# 4      [0.7281199879944324, -0.08245465097328027, 3.1...
# ...                                                  ...
# 33469  [2.1545800311224803, -1.8347450430904115, 0.75...
# 33470  [2.2244546473026277, 0.014246129989624023, 0.8...
# 33471  [2.1686178719003997, -0.04075054723458985, 1.7...
# 33472  [1.6086347728269175, -0.872624222189188, 1.566...
# 33473  [1.9644107164608107, -1.245211535029941, 0.376...
#
# [33474 rows x 8 columns]

# %%
X,y = data['embeddings'], data['Label']

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, f1_score, accuracy_score

from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
train_X, test_X, train_y, test_y = train_test_split(X,y, test_size = 0.2, random_state = 420)

# %%
svc = SVC(probability=True)

# %%
svc.fit(train_X.tolist(), train_y)
#svc.fit(train_X, train_y)
# Out:
# SVC(probability=True)

# %%
svc_pred = svc.predict(test_X.tolist())
# svc_pred = svc.predict(test_X)

# %%
print(confusion_matrix(test_y, svc_pred))
# Out:
# [[2184   53  519]
#  [ 317  185  482]
#  [ 454   56 2445]]

# %%
print(classification_report(test_y, svc_pred))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.74      0.79      0.76      2756
#            0       0.63      0.19      0.29       984
#            1       0.71      0.83      0.76      2955
#
#     accuracy                           0.72      6695
#    macro avg       0.69      0.60      0.61      6695
# weighted avg       0.71      0.72      0.69      6695

# %%
accuracy_score(test_y, svc_pred)
# Out:
# 0.7190440627333832

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
    max_depth=1, random_state=0).fit(train_X.tolist(), train_y)
gbc.score(test_X.tolist(), test_y)
# Out:
# 0.6716952949962659

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=0).fit(train_X.tolist(), train_y)



clf.score(test_X.tolist(), test_y)
# Out:
# /home/fm-pc-lt-228/anaconda3/envs/nepali/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 0.6776699029126214
